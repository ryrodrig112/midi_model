# %% [markdown]
# # Dev
# Data:
# - [PaJama Jazz Github and Docs](https://almostimplemented.github.io/PiJAMA/)
# - [PaJama Dataset Downloadh](https://zenodo.org/records/8354955)
# - [PaJama Paper](https://transactions.ismir.net/articles/10.5334/tismir.162#B15)
# ----
# MidiTok
# - [Data Loading](https://miditok.readthedocs.io/en/latest/pytorch_data.html)

# %% [markdown]
# ## Imports and Loads

# %%
from datasets import load_dataset;
import librosa;
import scipy.io.wavfile as wav
import os
import sys
import sys
sys.path.append("../")
sys.path.append("./")
import numpy as np
import matplotlib.pyplot as plt;
import itertools
import torch.nn as nn
import torch.nn.functional as F
import torch
from collections import OrderedDict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pretty_midi
from pathlib import Path
from collections import Counter
from tqdm import tqdm
from symusic import Score

# %matplotlib inline

# %%
from miditok import REMI, TokenizerConfig
import miditok

# %%
rootdir = ''
files = [os.path.join(root,file) for root, dirs, files in os.walk('../data/', topdown=True)
                     for file in files if file.endswith(".midi")]
n_files = len(files)

rng_idxs = np.random.default_rng().choice(a=n_files, size=n_files, replace=False)

# %%
tr_amt = int(n_files * .75)
val_amt = int(n_files * .125)
te_amt = n_files - (tr_amt + val_amt)
print(f"Total Train Files: {tr_amt}")
print(f"Total Val Files: {val_amt}")
print(f"Total Test Files: {te_amt}")

tr_idxs = rng_idxs[:tr_amt]
val_idxs = rng_idxs[tr_amt:tr_amt+val_amt]
te_idxs = rng_idxs[tr_amt+val_amt:]

tr_files = [files[i] for i in tr_idxs]
val_files = [files[i] for i in val_idxs]
te_files = [files[i] for i in te_idxs]
# Out:
# Total Train Files: 2082
# Total Val Files: 347
# Total Test Files: 348

# %%
def load_midi_to_pm(path):
    with open(path, 'rb') as m:
            return pretty_midi.PrettyMIDI(m)

def note_events(pmidi, start=0, end=0):
    notes = [note for instrument in pmidi.instruments for note in instrument.notes if note.start > start and note.end < end]
    return notes


def plot_piano_roll(pm, start_pitch, end_pitch, fs=100):
    # Use librosa's specshow function for displaying the piano roll
    librosa.display.specshow(pm.get_piano_roll(fs)[start_pitch:end_pitch],
                             hop_length=1, sr=fs, x_axis='time', y_axis='cqt_note',
                             fmin=pretty_midi.note_number_to_hz(start_pitch))

# %% [markdown]
# ## Data Viz

# %%
config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
tokenizer = REMI(config)
# Out:
# /var/folders/3_/f8wt55b12b5683gxyp7dcqyc0000gn/T/ipykernel_68382/1853999252.py:1: UserWarning: The special token PAD_None is present twice in your configuration. Skipping its duplicated occurrence.
#   config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)

# %%
# Loads a midi, converts to tokens, and back to a MIDI
midi = Score(files[2])
tokens = tokenizer(midi)  # calling the tokenizer will automatically detect MIDIs, paths and tokens
converted_back_midi = tokenizer(tokens)  # PyTorch, Tensorflow and Numpy tensors are supported
# Out:
# [Tempo(0, 120, 500000, 'Tick')]

# %%
midi_note_dist = []
track_time_dist = []
token_list = []

for file in tr_files:
    midi = Score(file)
    tok = tokenizer(midi)

    tpq = midi.ticks_per_quarter
    num_ticks = midi.end()
    num_quarter_notes = num_ticks / tpq
    bps = midi.tempos[0].qpm / 60 # song beats per minute / 60 to get bps
    song_len_in_s = num_quarter_notes * bps # assuming 120 bpm (2 quarter notes per second)
    
    midi_note_dist.append(len(tok.ids))
    track_time_dist.append(song_len_in_s)
    token_list.append(tok.tokens)
    
print(f"Avg Tokens Per File: {np.mean(score_lens)}")
print(f"Max Tokens Per File: {np.max(score_lens)}")
print(f"Min Tokens Per File: {np.min(score_lens)}")

print(f"Avg Time Per File: {int(np.mean(track_time_dist) // 60)}:{np.mean(track_time_dist) % 60:0.1}")
print(f"Max Time Per File: {int(np.max(track_time_dist) // 60)}:{np.mean(track_time_dist) % 60:0.1}")
print(f"Min Time Per File: {int(np.min(track_time_dist)// 60)}:{np.mean(track_time_dist) % 60:0.1}")
# Out:
# Avg Tokens Per File: 7961.8
# Max Tokens Per File: 33741
# Min Tokens Per File: 1676
# Avg Time Per File: 19:5e+00
# Max Time Per File: 155:5e+00
# Min Time Per File: 0:5e+00

# %%
plt.hist(track_time_dist);

# %%
plt.hist(midi_note_dist);

# %% [markdown]
# ## MidiTok

# %% [markdown]
# - `miditok.pytorch_data.DatasetMIDI`: loads midifiles and either: 1) tokenizes them on the fly, OR pretokenizes them and saves tokenIDs in memory
# - `miditok.pytorch_data.split_midis_for_training()`: dynamically splits a midi file into chunks appropriate for training

# %%
default_tokenizer.train(vocab_size=30000, model="BPE", iterator=token_list)

# %%
tokenizer
# Out:
# 368 tokens with ('T',) io format(one token stream), trained with BPE

# %%
config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
new_tokenizer = REMI(config)

new_tokenizer.train(vocab_size=30000, model="BPE", iterator=[tok])
# Out:
# /var/folders/3_/f8wt55b12b5683gxyp7dcqyc0000gn/T/ipykernel_68382/2925564045.py:1: UserWarning: The special token PAD_None is present twice in your configuration. Skipping its duplicated occurrence.
#   config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[175], line 4
#       1 config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
#       2 new_tokenizer = REMI(config)
# ----> 4 new_tokenizer.train(vocab_size=30000, model="BPE", iterator=[tok])
#
# File ~/PycharmProjects/personal/ood_music/lib/python3.9/site-packages/miditok/midi_tokenizer.py:2663, in MusicTokenizer.train(self, vocab_size, model, iterator, files_paths, **kwargs)
#    2655 name_trainer = f"{'Bpe' if model_name == 'BPE' else model_name}Trainer"
#    2656 trainer = getattr(_tok_trainers, name_trainer)(
# ...

# %%
file_paths = list(Path("..", "data", "midi").glob("**/*.midi"))

tr_file_paths = [file_path[i] for i in tr_idxs]

# %%
config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
tokenizer = REMI(config)
tokenizer.train(vocab_size=30000, files_paths=file_paths)
# Out:
# /var/folders/3_/f8wt55b12b5683gxyp7dcqyc0000gn/T/ipykernel_69391/3100609976.py:1: UserWarning: The special token PAD_None is present twice in your configuration. Skipping its duplicated occurrence.
#   config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)

# %%
tokenizer.vocab_model
# Out:
# {'ĺY\x85\x8fĺb': 20625,
#  'ĺ8\x86\x93': 13505,
#  'àĺY\x85\x92': 20187,
#  '\x84\x8fÑĺB': 21716,
#  'ĺ^\x86§': 13788,
#  'ÔĺU\x85\x8fÖ': 21809,
#  'ĺS\x87\x98': 8604,
#  '\x87\x96Ø': 16800,
#  'ĺY\x86«': 17206,
#  '\x87\x9b': 532,
#  '\x85\x90áĺF': 14911,
#  '\x83\x92é': 9660,
#  'ÙĺI\x84\x91': 26362,
#  'ĺ]\x86\x95ĺ`\x86\x95': 24937,
#  'ĺ=\x83\x9e': 14318,
#  'ĺV\x85\x8eĺ[': 15997,
#  'ĺO\x85\x90ĺR': 7227,
#  '\x86\x8eĺ>': 4434,
#  'ëĺP\x85\x8fí': 24912,
#  'ĺ]\x85\x8eè': 21138,
#  'ĺT\x85\x8eÜ': 26500,
#  'ĺI\x86\x9a': 5836,
#  'ëĺG': 1745,
#  'ßĺO': 3516,
#  'ĺC\x85\x90ĺJ': 23005,
#  'ĺR\x84\x93ĺV\x85\x93': 25521,
#  '\x83\x8eĺm': 24737,
#  '\x85\x8fâĺ9': 26118,
#  'ĺQ\x85\x8eĺS': 27219,
#  'ĺS\x82¡': 28868,
#  'ĺN\x85\x92ĺR\x85\x92': 11197,
#  'ĺa\x85\x8fÔ': 15826,
#  'ĺK\x83\x96': 2983,
#  '\x87\x97Ø': 26782,
#  '\x84\x98å': 8845,
#  'ÖĺM\x85\x91': 18529,
#  'áĺU\x85\x90': 12559,
#  '\x84\x92Ñ': 11148,
#  'ĺR\x86\x8fâ': 9066,
#  '%ÐĺW\x85\x93': 25312,
#  'ĺc\x87¡': 21145,
# ...

# %%
tokens = tokenizer(file_paths[0]) # Transform original to compressed version
print(tokens.ids[:10])
# Out:
# [8917, 3520, 2527, 402, 2564, 402, 2551, 1160, 2973, 382]

# %%
tokenizer.decode_token_ids(tokens) # Decode to original vocab
print(tokens.ids[:10])
# Out:
# [4, 180, 281, 23, 98, 156, 181, 281, 53, 99]
